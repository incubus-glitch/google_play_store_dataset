# %%
import pandas as pd

# %% [markdown]
# # Работа с Pandas

# %% [markdown]
# Загрузите ваш DataFrame в переменную df и выведете на экран первые пять строк

# %%
df = pd.read_csv('googleplaystore.csv') # ваш путь к файлу с данными
df.head()
# Out:
#                                                  App        Category  Rating
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1  \
# 1                                Coloring book moana  ART_AND_DESIGN     3.9
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN     4.7
# 3                              Sketch - Draw & Paint  ART_AND_DESIGN     4.5
# 4              Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN     4.3
#
#   Reviews  Size     Installs  Type  Price Content Rating
# 0     159   19M      10,000+  Free    0.0       Everyone  \
# 1     967   14M     500,000+  Free    0.0       Everyone
# 2   87510  8.7M   5,000,000+  Free    0.0       Everyone
# 3  215644   25M  50,000,000+  Free    0.0           Teen
# 4     967  2.8M     100,000+  Free    0.0       Everyone
#
#                       Genres      Last Updated         Current Ver
# 0               Art & Design   January 7, 2018               1.0.0  \
# 1  Art & Design;Pretend Play  January 15, 2018               2.0.0
# 2               Art & Design    August 1, 2018               1.2.4
# 3               Art & Design      June 8, 2018  Varies with device
# 4    Art & Design;Creativity     June 20, 2018                 1.1
#
#     Android Ver
# 0  4.0.3 and up
# 1  4.0.3 and up
# 2  4.0.3 and up
# 3    4.2 and up
# 4    4.4 and up

# %% [markdown]
# Отобразите количество строк и столбцов в DataFrame

# %%
df.shape
# Out:
# (10841, 13)

# %% [markdown]
# # PRO часть (Не обязательна к выполнению, но желательна :))

# %% [markdown]
# Измените названия всех столбцов приведя их к нижнему регистру

# %%
column_names = list(df.columns)

lower_column_names = []

for word in column_names:
    lower_column_names.append(word.lower())
    
df.columns = lower_column_names

# %% [markdown]
# Выведите основные статистики по категориальным столбцам. Напишите выводы о них

# %%
df.describe(include='object')
# Out:
#            app category reviews                size    installs   type
# count    10841    10841   10841               10841       10841  10840  \
# unique    9660       34    6002                 462          22      3
# top     ROBLOX   FAMILY       0  Varies with device  1,000,000+   Free
# freq         9     1972     596                1695        1579  10039
#
#        content rating genres    last updated         current ver android ver
# count           10840  10841           10841               10833       10838
# unique              6    120            1378                2832          33
# top          Everyone  Tools  August 3, 2018  Varies with device  4.1 and up
# freq             8714    842             326                1459        2451

# %% [markdown]
# count - число элементов<br>
# unique - число уникальных элементов<br>
# top - какой элемент встречался чаще всего<br>
# freq - сколько раз встречался этот элемент<br>

# %% [markdown]
# Выведите на экран часть датафрейма, который соответствует условию: `приложение из категории искусства и дизайна` И `с рейтингом больше 4.5`

# %%
df.loc[(df['category'] == 'ART_AND_DESIGN') & (df['rating'] > 4.5)]
# Out:
#                                 app category  rating   reviews
# 1656                      Solitaire     GAME     4.7    254258  \
# 1660                   Clash Royale     GAME     4.6  23133508
# 1664                   Block Puzzle     GAME     4.6     59800
# 1670                 Clash of Clans     GAME     4.6  44891723
# 1677            Bubble Witch 3 Saga     GAME     4.7   1732263
# ...                             ...      ...     ...       ...
# 10484  FJ Final Join , Circles Game     GAME     4.7        32
# 10679                    Solitaire+     GAME     4.6     11235
# 10697                       Mu.F.O.     GAME     5.0         2
# 10721             Mad Dash Fo' Cash     GAME     5.0        14
# 10776              Monster Ride Pro     GAME     5.0         1
#
#                      size      installs  type  price content rating    genres
# 1656                  23M   10,000,000+  Free   0.00       Everyone      Card  \
# 1660                  97M  100,000,000+  Free   0.00   Everyone 10+  Strategy
# 1664                 7.8M    5,000,000+  Free   0.00       Everyone    Puzzle
# 1670                  98M  100,000,000+  Free   0.00   Everyone 10+  Strategy
# 1677                  78M   50,000,000+  Free   0.00       Everyone    Puzzle
# ...                   ...           ...   ...    ...            ...       ...
# 10484                 24M        1,000+  Free   0.00           Teen    Arcade
# 10679  Varies with device      100,000+  Paid   2.99       Everyone      Card
# 10697                 16M            1+  Paid   0.99       Everyone    Arcade
# 10721                 16M          100+  Free   0.00       Everyone    Arcade
# 10776                 24M           10+  Free   0.00       Everyone    Racing
#
#          last updated         current ver         android ver
# 1656   August 1, 2018             2.137.0          4.1 and up
# 1660    June 27, 2018               2.3.2          4.1 and up
# 1664    March 6, 2018                 2.9          2.3 and up
# 1670    July 15, 2018           10.322.16          4.1 and up
# 1677    July 17, 2018               4.8.4          3.0 and up
# ...               ...                 ...                 ...
# 10484   July 11, 2018                0.24          4.3 and up
# 10679   July 30, 2018  Varies with device  Varies with device
# 10697   March 3, 2017                 1.0          2.3 and up
# 10721   June 19, 2017                2.5a          4.1 and up
# 10776   March 5, 2018                 2.0          2.3 and up
#
# [215 rows x 13 columns]

# %% [markdown]
# Посчитатайте какое количество игр содержится в рейтинге, используя параметр разбиения (bins) равным 100. Выведите на экран топ-10 игр по количеству в рейтинге. Напишите краткий вывод.
# То есть сначала отфильтровываете лишь игры из всего датафрейма, после чего применяете value_counts к столбцу с рейтингом используя параметр, который указан выше. И выводите первые 10 строк отсортированных по убыванию.

# %%
# Фильтруем только игры 
game_df = df[df['category'] == 'GAME']

# Используем метод value_counts для подсчета количества игр в каждом рейтинге
rating_counts = game_df['rating'].value_counts(bins=100)
print('Количество игр в каждом рейтинге: ' + str(rating_counts))

print('===================================================================================')

# Выводим топ-10 игр по количеству в рейтинге
top_10_games = game_df.sort_values(by='rating', ascending=False).head(10)
print(top_10_games[['app', 'rating']])
# Out:
# Количество игр в каждом рейтинге: rating
# (4.48, 4.52]    174
# (4.36, 4.4]     166
# (4.28, 4.32]    151
# (4.56, 4.6]     121
# (4.16, 4.2]     115
#                ...
# (3.04, 3.08]      0
# (1.04, 1.08]      0
# (1.84, 1.88]      0
# (2.92, 2.96]      0
# (3.0, 3.04]       0
# Name: count, Length: 100, dtype: int64
# ===================================================================================
#                                                app  rating
# 7698                                     CP Trivia     5.0
# 5917                                      Ra Ga Ba     5.0
# 9056                   Santa's Monster Shootout DX     5.0
# 5795                              Axe Champs! Wars     5.0
# 6700                              Brick Breaker BR     5.0
# 7466                                        211:CK     5.0
# 5822   Flippy Axe : Flip The Knife & Axe Simulator     5.0
# 9265                                      EC Mover     5.0
# 7402                          Trovami se ci riesci     5.0
# 10721                            Mad Dash Fo' Cash     5.0

# %% [markdown]
# <b>Выводы:</b><br>
# Наибольшее количество игр расположено в интервале с рейтингом около 4.5.<br>
# Игр с низким рейтингом нет.

# %% [markdown]
# Создайте функцию , которая будет применена к столбцу рейтинг методом `apply()`.
# Функция должна принимать строку с рейтингом и возвращать:
#  - High rating, если рейтинг больше или равен 4.5
#  - Middle rating, если рейтинг между 3.8 и 4.5
#  - Low rating, если рейтинг меньше 3.8
# Результат работы функции запишите в новый столбец с названием `categorical_rating`

# %%
def check_rating(rating: str) -> str:
    if rating >= 4.5:
        return 'High rating'
    elif rating >= 3.8 and rating < 4.5:
        return 'Middle rating'
    else:
        return 'Low rating'
    
df['rating'].apply(check_rating)
# Out:
# 0        Middle rating
# 1        Middle rating
# 2          High rating
# 3          High rating
# 4        Middle rating
#              ...
# 10836      High rating
# 10837      High rating
# 10838       Low rating
# 10839      High rating
# 10840      High rating
# Name: rating, Length: 10841, dtype: object

# %% [markdown]
# Выведите кол-во уникальных значений в столбцах отсортированных по убыванию на экран:

# %%
df.nunique().sort_values(ascending=False)
# Out:
# app               9660
# reviews           6002
# current ver       2832
# last updated      1378
# size               462
# genres             120
# price               92
# rating              40
# category            34
# android ver         33
# installs            22
# content rating       6
# type                 3
# dtype: int64

# %% [markdown]
# __Super-Hard задания__
#
# Решите задачу, где мы создавали свою собственную функцию, но вместо функции `def` используйте `лямбда-функцию` внутри `apply()`

# %%
df['rating'].apply(lambda x : 'High rating' if x >= 4.5 else ('Middle rating' if x >= 3.8 and x < 4.5 else 'Low rating'))
# Out:
# 0        Middle rating
# 1        Middle rating
# 2          High rating
# 3          High rating
# 4        Middle rating
#              ...
# 10836      High rating
# 10837      High rating
# 10838       Low rating
# 10839      High rating
# 10840      High rating
# Name: rating, Length: 10841, dtype: object

# %% [markdown]
# Изучите функцию `transform` в документации Pandas. Примените её к датафрейму, который будет заранее сгруппирован по столбцу `category`. С помощью фукнции `transform` найдите средний `rating` по каждой категории и запишите в столбец с названием `mean_cat_rating`. Кол-во строк в получившемся новом столбец должно быть таким же, как и в исходном датафрейме

# %%
df['mean_cat_reting'] = df.groupby('category')['rating'].transform('mean')
df
# Out:
#                                                      app             category
# 0         Photo Editor & Candy Camera & Grid & ScrapBook       ART_AND_DESIGN  \
# 1                                    Coloring book moana       ART_AND_DESIGN
# 2      U Launcher Lite – FREE Live Cool Themes, Hide ...       ART_AND_DESIGN
# 3                                  Sketch - Draw & Paint       ART_AND_DESIGN
# 4                  Pixel Draw - Number Art Coloring Book       ART_AND_DESIGN
# ...                                                  ...                  ...
# 10836                                   Sya9a Maroc - FR               FAMILY
# 10837                   Fr. Mike Schmitz Audio Teachings               FAMILY
# 10838                             Parkinson Exercices FR              MEDICAL
# 10839                      The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 10840      iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
#        rating reviews                size     installs  type  price
# 0         4.1     159                 19M      10,000+  Free    0.0  \
# 1         3.9     967                 14M     500,000+  Free    0.0
# 2         4.7   87510                8.7M   5,000,000+  Free    0.0
# 3         4.5  215644                 25M  50,000,000+  Free    0.0
# 4         4.3     967                2.8M     100,000+  Free    0.0
# ...       ...     ...                 ...          ...   ...    ...
# 10836     4.5      38                 53M       5,000+  Free    0.0
# 10837     5.0       4                3.6M         100+  Free    0.0
# 10838     NaN       3                9.5M       1,000+  Free    0.0
# 10839     4.5     114  Varies with device       1,000+  Free    0.0
# 10840     4.5  398307                 19M  10,000,000+  Free    0.0
#
#       content rating                     genres      last updated
# 0           Everyone               Art & Design   January 7, 2018  \
# 1           Everyone  Art & Design;Pretend Play  January 15, 2018
# 2           Everyone               Art & Design    August 1, 2018
# 3               Teen               Art & Design      June 8, 2018
# 4           Everyone    Art & Design;Creativity     June 20, 2018
# ...              ...                        ...               ...
# 10836       Everyone                  Education     July 25, 2017
# 10837       Everyone                  Education      July 6, 2018
# 10838       Everyone                    Medical  January 20, 2017
# 10839     Mature 17+          Books & Reference  January 19, 2015
# 10840       Everyone                  Lifestyle     July 25, 2018
#
#               current ver         android ver  mean_cat_reting
# 0                   1.0.0        4.0.3 and up         4.358065
# 1                   2.0.0        4.0.3 and up         4.358065
# 2                   1.2.4        4.0.3 and up         4.358065
# 3      Varies with device          4.2 and up         4.358065
# 4                     1.1          4.4 and up         4.358065
# ...                   ...                 ...              ...
# 10836                1.48          4.1 and up         4.192272
# 10837                 1.0          4.1 and up         4.192272
# 10838                 1.0          2.2 and up         4.189143
# 10839  Varies with device  Varies with device         4.346067
# 10840  Varies with device  Varies with device         4.094904
#
# [10841 rows x 14 columns]

# %% [markdown]
# Создайте функцию , которая будет применена к столбцу `last updated` и возвращать из него число месяца, если число месяца вернуть из строки невозможно, то верните вместо этого строку с значением `miss_date`.\
# Запишите полученный столбец в датафрейм , название столбцу дайте `day_of_update`.
#
# Если вы столкнётесь с некоторой ошибкой , которую вам выдаст Pandas, то изучите конструкцию Python `try` \ `except`.\
# Вот псевдокод , который поможет лучше разобраться с этой конструкцией:

# %%
import re

def number_of_month(date: str) -> str:
    try: # Помещаете то, что должно выполниться внутрь try, если же внутри try появляется ошибка, то условие переключается на оператор except и выполняется всё то, что находится внутри except.
        number = re.search(r'\b\d+\b', date)
        return number[0]
    except:
        return 'miss_date'

df['date_of_update'] = df['last updated'].apply(number_of_month)
df
# Out:
#                                                      app             category
# 0         Photo Editor & Candy Camera & Grid & ScrapBook       ART_AND_DESIGN  \
# 1                                    Coloring book moana       ART_AND_DESIGN
# 2      U Launcher Lite – FREE Live Cool Themes, Hide ...       ART_AND_DESIGN
# 3                                  Sketch - Draw & Paint       ART_AND_DESIGN
# 4                  Pixel Draw - Number Art Coloring Book       ART_AND_DESIGN
# ...                                                  ...                  ...
# 10836                                   Sya9a Maroc - FR               FAMILY
# 10837                   Fr. Mike Schmitz Audio Teachings               FAMILY
# 10838                             Parkinson Exercices FR              MEDICAL
# 10839                      The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 10840      iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
#        rating reviews                size     installs  type  price
# 0         4.1     159                 19M      10,000+  Free    0.0  \
# 1         3.9     967                 14M     500,000+  Free    0.0
# 2         4.7   87510                8.7M   5,000,000+  Free    0.0
# 3         4.5  215644                 25M  50,000,000+  Free    0.0
# 4         4.3     967                2.8M     100,000+  Free    0.0
# ...       ...     ...                 ...          ...   ...    ...
# 10836     4.5      38                 53M       5,000+  Free    0.0
# 10837     5.0       4                3.6M         100+  Free    0.0
# 10838     NaN       3                9.5M       1,000+  Free    0.0
# 10839     4.5     114  Varies with device       1,000+  Free    0.0
# 10840     4.5  398307                 19M  10,000,000+  Free    0.0
#
#       content rating                     genres      last updated
# 0           Everyone               Art & Design   January 7, 2018  \
# 1           Everyone  Art & Design;Pretend Play  January 15, 2018
# 2           Everyone               Art & Design    August 1, 2018
# 3               Teen               Art & Design      June 8, 2018
# 4           Everyone    Art & Design;Creativity     June 20, 2018
# ...              ...                        ...               ...
# 10836       Everyone                  Education     July 25, 2017
# 10837       Everyone                  Education      July 6, 2018
# 10838       Everyone                    Medical  January 20, 2017
# 10839     Mature 17+          Books & Reference  January 19, 2015
# 10840       Everyone                  Lifestyle     July 25, 2018
#
#               current ver         android ver  mean_cat_reting date_of_update
# 0                   1.0.0        4.0.3 and up         4.358065              7
# 1                   2.0.0        4.0.3 and up         4.358065             15
# 2                   1.2.4        4.0.3 and up         4.358065              1
# 3      Varies with device          4.2 and up         4.358065              8
# 4                     1.1          4.4 and up         4.358065             20
# ...                   ...                 ...              ...            ...
# 10836                1.48          4.1 and up         4.192272             25
# 10837                 1.0          4.1 and up         4.192272              6
# 10838                 1.0          2.2 and up         4.189143             20
# 10839  Varies with device  Varies with device         4.346067             19
# 10840  Varies with device  Varies with device         4.094904             25
#
# [10841 rows x 15 columns]
